# %%
# Load CSV from DBFS
df_bronze = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv("/FileStore/machine_failure_data.csv")

# Validate data loaded
print(f"Loaded {df_bronze.count()} rows")
display(df_bronze.limit(5))

# Save to Unity Catalog Delta table (replace with your catalog.schema)
df_bronze.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("main.default.bronze_machine_failure")
